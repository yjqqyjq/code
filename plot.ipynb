# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.loadtxt("/home/jyang/data/Flamingo/L0200N0360/M>1e14_offset_in.txt")
data2=np.loadtxt("/home/jyang/data/Flamingo/L0200N0360/M>1e14.txt")
O=data2[0]
fig = plt.figure()
ax=plt.subplot(1,1,1)
ax.scatter(O,data,s=1,label="M_tot>1e14")
ax.legend()
ax.set_xlabel("S")
ax.set_ylabel("Offset_in(0.1rvir)")
#ax.plot(np.linspace(0,0.06,20),np.linspace(0,0.06,20),color='red',linestyle='--')
# Out:
# Text(0, 0.5, 'Offset_in(0.1rvir)')
