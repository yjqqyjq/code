# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
path="/Users/24756376/data/Flamingo/L1000N0900/"
f=h5py.File(path+'S_compare_inside.hdf5','r')

#S_n=np.array(f["S_distance_neigh"])#no near halos
#S_sat=np.array(f["S_distance_sat"])#just central cluster
S=np.array(f["S_dist"])#everything
S_n=np.array(f["S_dist_nei"])
S_sat=np.array(f["S_dist_sat"])

f.close()
bins=np.linspace(0.4,2,15)

f=h5py.File(path+'S_dist.hdf5','r')
peak=np.array(f["bar_peak"])



f.close()

f=h5py.File("/Users/24756376/data/Flamingo/L1000N0900/halos_ranked.hdf5", 'r')
r200=np.array(f['r200'])

r50=np.array(f['r50'])
id=np.array(f['id'])
f.close()
r200=r200[r200!=0]
r50=r50[r50!=0]
#d=d/r50*r200
args=[12, 16,21,27, 40, 47,50,52,61,64,70,73,82, 93, 96, 101,107,112,121,139,141,146,153,160,167,173,187,191,192,196]

# %%
fig = plt.figure()
ax=plt.subplot(1,1,1)
bins=np.linspace(0,1.5,16)
bin=(bins[1:]+bins[:-1])/2
print(len(S_n[0]))

ax.legend()
per=np.percentile(S[(d==0)+(d>1.5)], [16, 50, 64], axis=0)
ax.plot(bin, per[1], label='without neighbor')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"$1-\sigma$")
per=np.percentile(S[(d>0)*(d<1.5)], [16, 50, 64], axis=0)
ax.plot(bin, per[1], label='with neighbor')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"$1-\sigma$")
ax.set_xlabel("Radius (r50)")
ax.set_ylabel("S")
ax.legend()
# Out:
# 15
# /var/folders/3t/dt29pzwn0vbbfncvrkg8lcl8g9q896/T/ipykernel_33975/4080319754.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
fig = plt.figure()
ax=plt.subplot(1,1,1)
bins=np.linspace(0,1.5,16)
bin=(bins[1:]+bins[:-1])/2
print(len(S_n[0]))

ax.legend()
per=np.percentile(S_n[(d==0)+(d>1.5)], [16, 50, 64], axis=0)
ax.plot(bin, per[1], label='without neighbor')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"$1-\sigma$")
per=np.percentile(S_n[(d>0)*(d<1.5)], [16, 50, 64], axis=0)
ax.plot(bin, per[1], label='with neighbor')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"$1-\sigma$")
ax.set_xlabel("Radius (r50)")
ax.set_ylabel("S")
ax.legend()
# Out:
# 15
# /var/folders/3t/dt29pzwn0vbbfncvrkg8lcl8g9q896/T/ipykernel_33975/1646680631.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
fig = plt.figure()
ax=plt.subplot(1,1,1)
bins=np.linspace(0,1.5,16)
bin=(bins[1:]+bins[:-1])/2
print(len(S_n[0]))

ax.legend()
per=np.percentile(S_sat[(d==0)+(d>1.5)], [16, 50, 64], axis=0)
ax.plot(bin, per[1], label='without neighbor')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"$1-\sigma$")
per=np.percentile(S_sat[(d>0)*(d<1.5)], [16, 50, 64], axis=0)
ax.plot(bin, per[1], label='with neighbor')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"$1-\sigma$")
ax.set_xlabel("Radius (r50)")
ax.set_ylabel("S")
ax.legend()
# Out:
# 15
# /var/folders/3t/dt29pzwn0vbbfncvrkg8lcl8g9q896/T/ipykernel_33975/2234644858.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
fig = plt.figure()
ax=plt.subplot(1,1,1)
ax.plot(bin, np.percentile(S, 50, axis=0), label='all')
ax.plot(bin, np.percentile(S_sat, 50, axis=0), label='without neighbor/satellites')
ax.plot(bin, np.percentile(S_n, 50, axis=0), label='without neighbor')
ax.legend()

# %%
fig = plt.figure()
ax=plt.subplot(1,1,1)
bins=np.linspace(0,1,11)
bin=(bins[1:]+bins[:-1])/2
print(len(args))

ax.legend()
per=np.percentile(S[args], [25, 50, 75], axis=0)
mask=np.isin(np.linspace(0,200,200,dtype=int), args,invert=True)
print(len(S[0:200][mask]))
per_nonD=np.percentile(S[0:200], [25, 50, 75], axis=0)
argss=np.arange(0,20,1)[np.argsort(S[:,9][0:20],kind="mergesort").astype(int)]
print(argss)
#for arg in argss:
#ax.plot(bin,S[arg])   
#      ax.plot(bin,S[arg],linestyle="dashed")
ax.plot(bin, per[1], label='Bullet Like')
ax.plot(bin, per_nonD[1], label='Non Bullet Like')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"Quarter")
ax.legend()
ax.set_xlabel("Radius (r50)")
ax.set_ylabel("S")
# Out:
# 30
# 170
# [13  1 14  3  4 18 11 12  6  5  8  2  0  7 16 10 19 15 17  9]
# /var/folders/3t/dt29pzwn0vbbfncvrkg8lcl8g9q896/T/ipykernel_61775/1983635221.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# Text(0, 0.5, 'S')

# %%
S50=S[:,4]
fig = plt.figure()
ax=plt.subplot(1,1,1)
ax.hist(S50[0:200],bins=20,alpha=0.5,density="True")
ax.hist(S50[args],bins=20,alpha=0.5,density="True")
print(np.argwhere(S50[0:200]<0.1))
print()
# Out:
# [[  1]
#  [  3]
#  [  4]
#  [ 11]
#  [ 14]
#  [ 18]
#  [ 21]
#  [ 24]
#  [ 25]
#  [ 31]
#  [ 33]
#  [ 35]
#  [ 37]
#  [ 38]
#  [ 42]
#  [ 46]
#  [ 49]
#  [ 50]
#  [ 51]
#  [ 54]
#  [ 58]
#  [ 59]
#  [ 60]
#  [ 61]
#  [ 63]
#  [ 64]
#  [ 65]
#  [ 76]
#  [ 77]
#  [ 82]
#  [ 89]
#  [ 91]
#  [ 94]
#  [ 95]
#  [ 96]
#  [ 97]
#  [ 98]
#  [ 99]
#  [105]
#  [106]
#  [109]
#  [110]
#  [111]
#  [115]
#  [117]
#  [125]
#  [128]
#  [129]
#  [137]
#  [138]
#  [139]
#  [143]
#  [146]
#  [149]
#  [150]
#  [162]
#  [164]
#  [167]
#  [168]
#  [170]
#  [171]
#  [172]
#  [174]
#  [175]
#  [177]
#  [179]
#  [180]
#  [181]
#  [186]
#  [189]
#  [192]
#  [193]
#  [197]
#  [198]
#  [199]]
# [12, 16, 21, 27, 40, 47, 50, 52, 61, 64, 70, 73, 82, 93, 96, 101, 107, 112, 121, 139, 141, 146, 153, 160, 167, 173, 187, 191, 192, 196]

# %%
fig = plt.figure()
ax=plt.subplot(1,1,1)
f=h5py.File("/Users/24756376/data/Flamingo/L1000N0900/satellites.hdf5",'r')
d=np.array(f["mms_dist"])
m=np.array(f["mms_mass_ratio"])
ax.scatter(S[:,8],S[:,9])
print(d[args],args)
# Out:
# [0.08032245 0.2141735  0.1625781  0.43120202 0.17487741 2.46215445
#  1.59704053 0.09554763 1.72342742 0.10799651 0.13061842 0.07749484
#  2.20762612 1.34523194 0.07729582 0.41873328 0.81571296 0.24187871
#  0.19803472 1.65058658 2.50091502 0.18529572 1.21788586 0.4534595
#  0.10640693 0.4042603  0.24782625 0.06326003 0.16319405 0.30417229] [12, 16, 21, 27, 40, 47, 50, 52, 61, 64, 70, 73, 82, 93, 96, 101, 107, 112, 121, 139, 141, 146, 153, 160, 167, 173, 187, 191, 192, 196]

# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
import functions as fn
from scipy.stats import spearmanr,pearsonr
f=h5py.File("/Users/24756376/data/Flamingo/L1000N1800/S_compare.hdf5",'r')


S_dist=np.array(f["S_dist"])
f.close()


#index_100=np.argwhere(S_c>S_m)
f=h5py.File("/Users/24756376/data/Flamingo/L1000N1800_NoCool/S_compare.hdf5",'r')


S_dist_ad=np.array(f["S_dist"])
f.close()
bins=np.linspace(0,1,11)
bin=(bins[1:]+bins[:-1])/2
f=h5py.File("/Users/24756376/data/Flamingo/L1000N1800/same_halos.hdf5",'r')
same_id=np.array(f["ids"])
f.close()
f=h5py.File("/Users/24756376/data/Flamingo/L1000N1800_NoCool/same_halos.hdf5",'r')
same_id_ad=np.array(f["ids"])
f.close()
per=np.percentile(S_dist[same_id], [25, 50, 75], axis=0)
per_ad=np.percentile(S_dist_ad[same_id_ad], [25, 50, 75], axis=0)
fig = plt.figure()
ax=plt.subplot(1,1,1)
ax.plot(bin, per[1], label='Hydro')
ax.fill_between(bin, per[0],per[2], facecolor='gray', alpha=.5, label=r"Quarter")
ax.plot(bin, per_ad[1], label='Adiabatic')
ax.legend()
