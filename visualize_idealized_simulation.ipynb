# %%
import numpy as np
import matplotlib.pyplot as plt
import unyt
import swiftsimio as sw
import h5py
#xray_lum offset>0.2:2.,  13.,  21.,  50.,  64.,  66.,  82., 105
path="/home/jyang/data/Flamingo/L0200N0360/halo_particles/"


f=h5py.File(path+'64.hdf5','r')

Coord_g=f['PartType1']["Coordinates"]
Coord_dm=f['PartType1']["Coordinates"]
xyz_dm=np.array(Coord_dm).T 
xyz_g=np.array(Coord_g).T
xray_lum=np.array(f['PartType1']['xray_lum_rosat'])
T=np.array(f['PartType1']['temperatures'])
f.close()
x_dm=xyz_dm[0]
y_dm=xyz_dm[2]
x_g=xyz_g[0]
y_g=xyz_g[2]

# %%
np.savetxt('../data/idealizedsim/1.00000_0.79057_15.000000/xdm.txt',x_dm)
np.savetxt('../data/idealizedsim/1.00000_0.79057_15.000000/xg.txt',x_g)
np.savetxt('../data/idealizedsim/1.00000_0.79057_15.000000/ydm.txt',y_dm)
np.savetxt('../data/idealizedsim/1.00000_0.79057_15.000000/yg.txt',y_g)

# %%
import matplotlib.pyplot as plt
from matplotlib import colors

#  x=np.append(x_dm[i],x_g[i])
#  y=np.append(y_dm[i],y_g[i])
fig = plt.figure()
ax=plt.subplot(1,1,1)

h=ax.hist2d(x_dm,y_dm,bins=100,norm=colors.LogNorm(),weights=T)
print(xray_lum)
xc=x_g[xray_lum==np.max(xray_lum)]
yc=y_g[xray_lum==np.max(xray_lum)]
ax.scatter(xc,yc,color='r',s=1)
ax.scatter(0,0,color='k',s=1)
'''
  plt.colorbar(h[3], ax=ax)
  if i<10:
    fig.savefig('../plot/idealizedsim/1.00000_0.79057_15.000000/xydm0'+str(i)+'0.png')
  else:

    fig.savefig('../plot/idealizedsim/1.00000_0.79057_15.000000/xydm'+str(i)+'0.png')
  plt.close(fig)'
'''
# Out:
# [ 316.74708076 1151.98861932  150.95896029 ...  148.92079498  146.31289759
#   196.11569369]
# "\n  plt.colorbar(h[3], ax=ax)\n  if i<10:\n    fig.savefig('../plot/idealizedsim/1.00000_0.79057_15.000000/xydm0'+str(i)+'0.png')\n  else:\n\n    fig.savefig('../plot/idealizedsim/1.00000_0.79057_15.000000/xydm'+str(i)+'0.png')\n  plt.close(fig)'\n"

# %%
plt.imshow(hist_g[0],norm=colors.LogNorm())
plt.colorbar()

# %%
plt.imshow(ratio)
plt.colorbar()
plt.title('Ratio of hist_g to hist_dm')
plt.show()
